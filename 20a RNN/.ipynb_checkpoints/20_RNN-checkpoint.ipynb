# %%
# Part 1 — Load & Explore the Dataset

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("monthly_milk_production.csv")
df.head()
# Out:
#       Date  Production
# 0  1962-01         589
# 1  1962-02         561
# 2  1962-03         640
# 3  1962-04         656
# 4  1962-05         727

# %%
print("Shape:", df.shape)

print("\nColumns:")
print(df.columns)

print("\nData Types:")
print(df.dtypes)

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Shape: (168, 2)
#
# Columns:
# Index(['Date', 'Production'], dtype='object')
#
# Data Types:
# Date          object
# Production     int64
# dtype: object
#
# Missing Values:
# Date          0
# Production    0
# dtype: int64

# %%
df["Date"] = pd.to_datetime(df["Date"])
df = df.sort_values("Date").reset_index(drop=True)
df.head()
# Out:
#         Date  Production
# 0 1962-01-01         589
# 1 1962-02-01         561
# 2 1962-03-01         640
# 3 1962-04-01         656
# 4 1962-05-01         727

# %%
print(df["Production"].describe())
# Out:
# count    168.000000
# mean     754.708333
# std      102.204524
# min      553.000000
# 25%      677.750000
# 50%      761.000000
# 75%      824.500000
# max      969.000000
# Name: Production, dtype: float64

# %%
plt.figure(figsize=(12, 5))

plt.plot(
    df["Date"],
    df["Production"]
)

plt.title("Monthly Milk Production")
plt.xlabel("Date")
plt.ylabel("Milk Production")

plt.grid(True)
plt.show()

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
Q1 = df["Production"].quantile(0.25)
Q3 = df["Production"].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[
    (df["Production"] < lower_bound) |
    (df["Production"] > upper_bound)
]

print("Number of outliers:", len(outliers))
print(outliers)
# Out:
# Number of outliers: 0
# Empty DataFrame
# Columns: [Date, Production]
# Index: []

# %%
# EDA Observations:
# The dataset contains 168 monthly milk production records with two variables: Date and Production.

# The Date column was converted into datetime format and the observations were sorted chronologically. The dataset contains no missing values.

# The time-series plot is used to identify the overall production trend, seasonal patterns, and unusual observations. Descriptive statistics and the IQR method are also used to investigate the distribution and possible outliers in milk production.

# The observed temporal structure will be considered when preparing input-output sequences for the RNN, LSTM, and GRU models.

# %%
# Part 2 — Scaling & Time-Series Sequence Preparation

data = df["Production"].values.reshape(-1, 1)

print("Data shape:", data.shape)
# Out:
# Data shape: (168, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaled_data = scaler.fit_transform(data)

print("Minimum:", scaled_data.min())
print("Maximum:", scaled_data.max())
# Out:
# Minimum: 0.0
# Maximum: 1.0000000000000002

# %%
n = len(scaled_data)

train_size = int(n * 0.70)
val_size = int(n * 0.15)

print("Total:", n)
print("Training:", train_size)
print("Validation:", val_size)
print("Test:", n - train_size - val_size)
# Out:
# Total: 168
# Training: 117
# Validation: 25
# Test: 26

# %%
train_data = data[:train_size]

val_data = data[train_size:train_size + val_size]

test_data = data[
    train_size + val_size:
]

print("Train:", train_data.shape)
print("Validation:", val_data.shape)
print("Test:", test_data.shape)
# Out:
# Train: (117, 1)
# Validation: (25, 1)
# Test: (26, 1)

# %%
scaler = MinMaxScaler()

train_scaled = scaler.fit_transform(train_data)

val_scaled = scaler.transform(val_data)

test_scaled = scaler.transform(test_data)

# %%
window_size = 12

# %%
def create_sequences(data, window_size):
    
    X = []
    y = []
    
    for i in range(window_size, len(data)):
        X.append(data[i-window_size:i])
        y.append(data[i])
    
    return np.array(X), np.array(y)

# %%
X_train, y_train = create_sequences(
    train_scaled,
    window_size
)

X_val, y_val = create_sequences(
    val_scaled,
    window_size
)

X_test, y_test = create_sequences(
    test_scaled,
    window_size
)

# %%
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)

print("X_val:", X_val.shape)
print("y_val:", y_val.shape)

print("X_test:", X_test.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (105, 12, 1)
# y_train: (105, 1)
# X_val: (13, 12, 1)
# y_val: (13, 1)
# X_test: (14, 12, 1)
# y_test: (14, 1)

# %%
# Data Preparation for Deep Learning:
# The milk production data was divided chronologically into training, validation, and test sets to preserve the temporal order of the observations.

# Min-Max scaling was applied to normalize the production values to a range between 0 and 1. The scaler was fitted only on the training data to prevent information from the validation and test periods from leaking into the training process.

# A 12-month sliding window was selected to create input-output sequences. Each input sequence contains the previous 12 months of milk production, while the corresponding target represents production for the following month.

# The resulting three-dimensional input structure is suitable for RNN, LSTM, and GRU models.

# %%
# Part 3 — Build the Basic RNN

import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from tensorflow.keras.optimizers import Adam

# %%
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.21.0

# %%
rnn_model = Sequential([
    SimpleRNN(
        50,
        activation="tanh",
        input_shape=(window_size, 1)
    ),
    
    Dense(1)
])

rnn_model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss="mse"
)

rnn_model.summary()
# Out:
# C:\Users\Administrator\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)               │ (None, 50)                  │           2,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,651 (10.36 KB)
#  Trainable params: 2,651 (10.36 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_rnn = rnn_model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 0.0542 - val_loss: 0.0125
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0152 - val_loss: 0.0600
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0129 - val_loss: 0.0115
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0077 - val_loss: 0.0090
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0059 - val_loss: 0.0148
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0053 - val_loss: 0.0094
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0048 - val_loss: 0.0066
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0037 - val_loss: 0.0082
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0039 - val_loss: 0.0066
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0033 - val_loss: 0.0044
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0029 - val_loss: 0.0054
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0028 - val_loss: 0.0042
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0024 - val_loss: 0.0041
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0025 - val_loss: 0.0035
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0022 - val_loss: 0.0043
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0021 - val_loss: 0.0033
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0020 - val_loss: 0.0034
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0020 - val_loss: 0.0029
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0019 - val_loss: 0.0028
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0014 - val_loss: 0.0030
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0014 - val_loss: 0.0030
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0014 - val_loss: 0.0029
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0015 - val_loss: 0.0039
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0015 - val_loss: 0.0038
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0015 - val_loss: 0.0040
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0020 - val_loss: 0.0084
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0016 - val_loss: 0.0039
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0016 - val_loss: 0.0041
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0013 - val_loss: 0.0030
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0013 - val_loss: 0.0026
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0014 - val_loss: 0.0035
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0014 - val_loss: 0.0030
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0013 - val_loss: 0.0035

# %%
plt.figure(figsize=(10, 5))

plt.plot(
    history_rnn.history["loss"],
    label="Training Loss"
)

plt.plot(
    history_rnn.history["val_loss"],
    label="Validation Loss"
)

plt.title("Basic RNN Training vs Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.legend()
plt.grid(True)

plt.show()

# %%
rnn_pred_scaled = rnn_model.predict(
    X_test
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step

# %%
rnn_pred = scaler.inverse_transform(
    rnn_pred_scaled
)

y_test_actual = scaler.inverse_transform(
    y_test
)

# %%
plt.figure(figsize=(12, 5))

plt.plot(
    y_test_actual,
    label="Actual"
)

plt.plot(
    rnn_pred,
    label="RNN Predicted"
)

plt.title("Basic RNN — Actual vs Predicted Milk Production")
plt.xlabel("Test Time Step")
plt.ylabel("Milk Production")
plt.legend()
plt.grid(True)

plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

rmse_rnn = np.sqrt(
    mean_squared_error(
        y_test_actual,
        rnn_pred
    )
)

mae_rnn = mean_absolute_error(
    y_test_actual,
    rnn_pred
)

mape_rnn = np.mean(
    np.abs(
        (y_test_actual - rnn_pred) /
        y_test_actual
    )
) * 100

print("RNN Performance")
print("----------------")
print("RMSE:", rmse_rnn)
print("MAE :", mae_rnn)
print("MAPE:", mape_rnn, "%")
# Out:
# RNN Performance
# ----------------
# RMSE: 13.239509170260204
# MAE : 10.712367466517874
# MAPE: 1.2654213058416348 %

# %%
# Basic RNN Model:
# A basic Recurrent Neural Network (RNN) was developed to forecast monthly milk production. The model uses a 12-month historical window as input and predicts the production value for the following month.

# The model consists of a SimpleRNN layer followed by a Dense output layer. The Adam optimizer and Mean Squared Error (MSE) loss function were used for training.

# # The model was trained using the training sequences while validation data was used to monitor its performance during training. Predictions were converted back to the original production scale and evaluated using RMSE, MAE, and MAPE.

# %%
# Part 4 — Build the LSTM Model

from tensorflow.keras.layers import LSTM

# %%
lstm_model = Sequential([
    LSTM(
        50,
        activation="tanh",
        input_shape=(window_size, 1)
    ),
    
    Dense(1)
])

lstm_model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss="mse"
)

lstm_model.summary()
# Out:
# C:\Users\Administrator\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 50)                  │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 10,451 (40.82 KB)
#  Trainable params: 10,451 (40.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_lstm = lstm_model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 160ms/step - loss: 0.1997 - val_loss: 0.2706
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0798 - val_loss: 0.0555
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0319 - val_loss: 0.0484
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0390 - val_loss: 0.0295
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0312 - val_loss: 0.0394
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0318 - val_loss: 0.0362
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0298 - val_loss: 0.0289
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0286 - val_loss: 0.0276
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0287 - val_loss: 0.0277
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0280 - val_loss: 0.0272
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0275 - val_loss: 0.0266
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0273 - val_loss: 0.0263
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0274 - val_loss: 0.0267
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0265 - val_loss: 0.0258
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0260 - val_loss: 0.0255
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0253 - val_loss: 0.0246
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0249 - val_loss: 0.0244
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0242 - val_loss: 0.0245
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0243 - val_loss: 0.0247
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0235 - val_loss: 0.0222
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0225 - val_loss: 0.0230
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0214 - val_loss: 0.0247
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 0.0212 - val_loss: 0.0241
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0195 - val_loss: 0.0195
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - loss: 0.0193 - val_loss: 0.0291
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0174 - val_loss: 0.0195
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0163 - val_loss: 0.0261
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0148 - val_loss: 0.0237
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0134 - val_loss: 0.0204
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0119 - val_loss: 0.0437
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0104 - val_loss: 0.0108
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0089 - val_loss: 0.0256
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0070 - val_loss: 0.0053
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0089 - val_loss: 0.0048
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0078 - val_loss: 0.0049
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0075 - val_loss: 0.0051
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0067 - val_loss: 0.0284
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0068 - val_loss: 0.0171
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0062 - val_loss: 0.0090
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0049 - val_loss: 0.0091
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0041 - val_loss: 0.0048
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0039 - val_loss: 0.0054
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0037 - val_loss: 0.0056
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0037 - val_loss: 0.0062
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0036 - val_loss: 0.0073
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0039 - val_loss: 0.0074
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0034 - val_loss: 0.0052
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0036 - val_loss: 0.0076
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0039 - val_loss: 0.0096
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0032 - val_loss: 0.0068
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0035 - val_loss: 0.0055
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0041 - val_loss: 0.0067
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0041 - val_loss: 0.0058
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0040 - val_loss: 0.0100
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0046 - val_loss: 0.0058
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0039 - val_loss: 0.0058
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0042 - val_loss: 0.0077
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0037 - val_loss: 0.0076
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0032 - val_loss: 0.0097
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0036 - val_loss: 0.0059
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0036 - val_loss: 0.0066
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0038 - val_loss: 0.0058
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0034 - val_loss: 0.0099
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0038 - val_loss: 0.0070
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0032 - val_loss: 0.0063
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0034 - val_loss: 0.0064
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0069 - val_loss: 0.0222
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0053 - val_loss: 0.0167
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0041 - val_loss: 0.0115
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0043 - val_loss: 0.0062
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0035 - val_loss: 0.0055
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0041 - val_loss: 0.0072
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0046 - val_loss: 0.0128
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0041 - val_loss: 0.0092
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0036 - val_loss: 0.0075
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0036 - val_loss: 0.0113
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0045 - val_loss: 0.0056
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0046 - val_loss: 0.0070
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0056 - val_loss: 0.0112
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 0.0042 - val_loss: 0.0112
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0038 - val_loss: 0.0084
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0035 - val_loss: 0.0059
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0041 - val_loss: 0.0065
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0040 - val_loss: 0.0099
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0033 - val_loss: 0.0094
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0036 - val_loss: 0.0054
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.0033 - val_loss: 0.0116
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0038 - val_loss: 0.0108
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0032 - val_loss: 0.0056
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0041 - val_loss: 0.0066
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0037 - val_loss: 0.0137
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0034 - val_loss: 0.0057
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0030 - val_loss: 0.0072
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0032 - val_loss: 0.0076
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0030 - val_loss: 0.0069
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0030 - val_loss: 0.0097
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0036 - val_loss: 0.0085
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0030 - val_loss: 0.0085
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0031 - val_loss: 0.0056
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0035 - val_loss: 0.0056

# %%
plt.figure(figsize=(10, 5))

plt.plot(
    history_lstm.history["loss"],
    label="Training Loss"
)

plt.plot(
    history_lstm.history["val_loss"],
    label="Validation Loss"
)

plt.title("LSTM Training vs Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.legend()
plt.grid(True)

plt.show()

# %%
lstm_pred_scaled = lstm_model.predict(
    X_test
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step

# %%
lstm_pred = scaler.inverse_transform(
    lstm_pred_scaled
)

# %%
plt.figure(figsize=(12, 5))

plt.plot(
    y_test_actual,
    label="Actual"
)

plt.plot(
    lstm_pred,
    label="LSTM Predicted"
)

plt.title("LSTM — Actual vs Predicted Milk Production")
plt.xlabel("Test Time Step")
plt.ylabel("Milk Production")
plt.legend()
plt.grid(True)

plt.show()

# %%
rmse_lstm = np.sqrt(
    mean_squared_error(
        y_test_actual,
        lstm_pred
    )
)

mae_lstm = mean_absolute_error(
    y_test_actual,
    lstm_pred
)

mape_lstm = np.mean(
    np.abs(
        (y_test_actual - lstm_pred) /
        y_test_actual
    )
) * 100

print("LSTM Performance")
print("-----------------")
print("RMSE:", rmse_lstm)
print("MAE :", mae_lstm)
print("MAPE:", mape_lstm, "%")
# Out:
# LSTM Performance
# -----------------
# RMSE: 29.078995560394702
# MAE : 25.335344587053573
# MAPE: 2.9609237607927446 %

# %%
# LSTM Model:
# A Long Short-Term Memory (LSTM) network was developed for monthly milk production forecasting. LSTM is a recurrent neural network architecture designed to learn dependencies in sequential data.

# The LSTM receives the previous 12 months of production as input and predicts the following month's production. The model was trained using the training data and monitored using the validation set.

# The predictions were converted back to the original production scale and evaluated using RMSE, MAE, and MAPE.

# %%
# Part 5 — Build the GRU Model

from tensorflow.keras.layers import GRU

# %%
gru_model = Sequential([
    GRU(
        50,
        activation="tanh",
        input_shape=(window_size, 1)
    ),
    
    Dense(1)
])

gru_model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss="mse"
)

gru_model.summary()
# Out:
# C:\Users\Administrator\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 50)                  │           7,950 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,001 (31.25 KB)
#  Trainable params: 8,001 (31.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_gru = gru_model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 169ms/step - loss: 0.1920 - val_loss: 0.2533
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0696 - val_loss: 0.0660
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0332 - val_loss: 0.0296
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0398 - val_loss: 0.0285
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0325 - val_loss: 0.0373
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0301 - val_loss: 0.0492
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0296 - val_loss: 0.0435
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0277 - val_loss: 0.0361
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0271 - val_loss: 0.0290
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0269 - val_loss: 0.0288
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0259 - val_loss: 0.0308
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0250 - val_loss: 0.0323
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0245 - val_loss: 0.0314
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0239 - val_loss: 0.0282
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0233 - val_loss: 0.0272
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0227 - val_loss: 0.0273
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0221 - val_loss: 0.0272
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0217 - val_loss: 0.0250
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0211 - val_loss: 0.0252
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0208 - val_loss: 0.0262
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0203 - val_loss: 0.0235
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0196 - val_loss: 0.0238
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0193 - val_loss: 0.0240
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0189 - val_loss: 0.0207
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.0186 - val_loss: 0.0206
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0182 - val_loss: 0.0242
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0176 - val_loss: 0.0215
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0172 - val_loss: 0.0189
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0168 - val_loss: 0.0196
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0164 - val_loss: 0.0205
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0160 - val_loss: 0.0206
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0156 - val_loss: 0.0181
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0153 - val_loss: 0.0181
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0150 - val_loss: 0.0187
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0146 - val_loss: 0.0176
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0142 - val_loss: 0.0181
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0139 - val_loss: 0.0178
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0135 - val_loss: 0.0157
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0132 - val_loss: 0.0180
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0128 - val_loss: 0.0158
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0125 - val_loss: 0.0176
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0121 - val_loss: 0.0143
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0117 - val_loss: 0.0171
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0113 - val_loss: 0.0129
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0110 - val_loss: 0.0143
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0104 - val_loss: 0.0157
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0100 - val_loss: 0.0114
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0095 - val_loss: 0.0109
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0091 - val_loss: 0.0112
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0084 - val_loss: 0.0089
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0082 - val_loss: 0.0092
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0080 - val_loss: 0.0086
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0073 - val_loss: 0.0087
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0073 - val_loss: 0.0086
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0070 - val_loss: 0.0088
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0069 - val_loss: 0.0085
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0074 - val_loss: 0.0224
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0096 - val_loss: 0.0106
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0079 - val_loss: 0.0096
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.0076 - val_loss: 0.0081
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0070 - val_loss: 0.0086
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0065 - val_loss: 0.0079
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0064 - val_loss: 0.0091
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0063 - val_loss: 0.0077
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0065 - val_loss: 0.0083
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0062 - val_loss: 0.0087
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0065 - val_loss: 0.0076
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0064 - val_loss: 0.0106
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0078 - val_loss: 0.0117
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0071 - val_loss: 0.0107
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0067 - val_loss: 0.0072
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0056 - val_loss: 0.0087
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0062 - val_loss: 0.0070
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0055 - val_loss: 0.0070
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0053 - val_loss: 0.0081
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0054 - val_loss: 0.0071
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0054 - val_loss: 0.0071
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0052 - val_loss: 0.0070
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0054 - val_loss: 0.0081
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0053 - val_loss: 0.0072
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0049 - val_loss: 0.0072
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0047 - val_loss: 0.0072
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0047 - val_loss: 0.0070
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0049 - val_loss: 0.0077
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0048 - val_loss: 0.0091
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0045 - val_loss: 0.0068
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 197ms/step - loss: 0.0045 - val_loss: 0.0122
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0063 - val_loss: 0.0120
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0056 - val_loss: 0.0107
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0047 - val_loss: 0.0072
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0047 - val_loss: 0.0077
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0044 - val_loss: 0.0072
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0045 - val_loss: 0.0093
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0048 - val_loss: 0.0075
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0042 - val_loss: 0.0085
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0044 - val_loss: 0.0074
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0042 - val_loss: 0.0085
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0041 - val_loss: 0.0076
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0042 - val_loss: 0.0084

# %%
plt.figure(figsize=(10, 5))

plt.plot(
    history_gru.history["loss"],
    label="Training Loss"
)

plt.plot(
    history_gru.history["val_loss"],
    label="Validation Loss"
)

plt.title("GRU Training vs Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.legend()
plt.grid(True)

plt.show()

# %%
gru_pred_scaled = gru_model.predict(
    X_test
)

gru_pred = scaler.inverse_transform(
    gru_pred_scaled
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step

# %%
plt.figure(figsize=(12, 5))

plt.plot(
    y_test_actual,
    label="Actual"
)

plt.plot(
    gru_pred,
    label="GRU Predicted"
)

plt.title("GRU — Actual vs Predicted Milk Production")
plt.xlabel("Test Time Step")
plt.ylabel("Milk Production")
plt.legend()
plt.grid(True)

plt.show()

# %%
rmse_gru = np.sqrt(
    mean_squared_error(
        y_test_actual,
        gru_pred
    )
)

mae_gru = mean_absolute_error(
    y_test_actual,
    gru_pred
)

mape_gru = np.mean(
    np.abs(
        (y_test_actual - gru_pred) /
        y_test_actual
    )
) * 100

print("GRU Performance")
print("----------------")
print("RMSE:", rmse_gru)
print("MAE :", mae_gru)
print("MAPE:", mape_gru, "%")
# Out:
# GRU Performance
# ----------------
# RMSE: 31.967451047737768
# MAE : 28.96552821568082
# MAPE: 3.4006775417115755 %

# %%
# GRU Model:
# A Gated Recurrent Unit (GRU) network was developed to forecast monthly milk production.

# The GRU uses the previous 12 months of production as input and predicts the following month's production. The model was trained using the training sequences, while the validation data was used to monitor model performance.

# The predictions were transformed back to the original production scale and evaluated using RMSE, MAE, and MAPE.

# %%
# Part 6 — Compare RNN, LSTM, and GRU

model_comparison = pd.DataFrame({
    "Model": [
        "Basic RNN",
        "LSTM",
        "GRU"
    ],
    "RMSE": [
        rmse_rnn,
        rmse_lstm,
        rmse_gru
    ],
    "MAE": [
        mae_rnn,
        mae_lstm,
        mae_gru
    ],
    "MAPE (%)": [
        mape_rnn,
        mape_lstm,
        mape_gru
    ]
})

model_comparison
# Out:
#        Model       RMSE        MAE  MAPE (%)
# 0  Basic RNN  13.239509  10.712367  1.265421
# 1       LSTM  29.078996  25.335345  2.960924
# 2        GRU  31.967451  28.965528  3.400678

# %%
model_comparison = pd.DataFrame({
    "Model": [
        "Basic RNN",
        "LSTM",
        "GRU"
    ],
    "RMSE": [
        rmse_rnn,
        rmse_lstm,
        rmse_gru
    ],
    "MAE": [
        mae_rnn,
        mae_lstm,
        mae_gru
    ],
    "MAPE (%)": [
        mape_rnn,
        mape_lstm,
        mape_gru
    ]
})

model_comparison
# Out:
#        Model       RMSE        MAE  MAPE (%)
# 0  Basic RNN  13.239509  10.712367  1.265421
# 1       LSTM  29.078996  25.335345  2.960924
# 2        GRU  31.967451  28.965528  3.400678

# %%
best_rmse_model = model_comparison.loc[
    model_comparison["RMSE"].idxmin(),
    "Model"
]

best_mae_model = model_comparison.loc[
    model_comparison["MAE"].idxmin(),
    "Model"
]

best_mape_model = model_comparison.loc[
    model_comparison["MAPE (%)"].idxmin(),
    "Model"
]

print("Best RMSE:", best_rmse_model)
print("Best MAE :", best_mae_model)
print("Best MAPE:", best_mape_model)
# Out:
# Best RMSE: Basic RNN
# Best MAE : Basic RNN
# Best MAPE: Basic RNN

# %%
model_comparison.set_index("Model")[
    ["RMSE", "MAE", "MAPE (%)"]
].plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("RNN vs LSTM vs GRU Performance")
plt.xlabel("Model")
plt.ylabel("Error")
plt.xticks(rotation=0)
plt.grid(axis="y")

plt.show()

# %%
# Model Comparison:
# The Basic RNN, LSTM, and GRU models were evaluated using RMSE, MAE, and MAPE.

# RMSE measures the square root of the average squared prediction error, while MAE measures the average absolute prediction error. MAPE expresses the prediction error as a percentage of the actual values.

# For all three metrics, lower values indicate better forecasting performance. The model comparison table and visualization are used to identify the model that provides the most accurate predictions on the test dataset.

# The best-performing model is selected based on its overall forecasting error across the evaluation metrics.

# %%
# Part 7 — Hyperparameter Tuning

best_model_name = model_comparison.loc[
    model_comparison["RMSE"].idxmin(),
    "Model"
]

print("Best architecture based on RMSE:", best_model_name)
# Out:
# Best architecture based on RMSE: Basic RNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, LSTM, GRU, Dense
from tensorflow.keras.optimizers import Adam


def build_model(
    model_type,
    units=50,
    learning_rate=0.001
):
    
    model = Sequential()
    
    if model_type == "Basic RNN":
        model.add(
            SimpleRNN(
                units,
                activation="tanh",
                input_shape=(window_size, 1)
            )
        )
        
    elif model_type == "LSTM":
        model.add(
            LSTM(
                units,
                activation="tanh",
                input_shape=(window_size, 1)
            )
        )
        
    elif model_type == "GRU":
        model.add(
            GRU(
                units,
                activation="tanh",
                input_shape=(window_size, 1)
            )
        )
    
    model.add(Dense(1))
    
    model.compile(
        optimizer=Adam(
            learning_rate=learning_rate
        ),
        loss="mse"
    )
    
    return model

# %%
param_grid = [
    {"units": 32, "learning_rate": 0.001},
    {"units": 32, "learning_rate": 0.0005},
    {"units": 64, "learning_rate": 0.001},
    {"units": 64, "learning_rate": 0.0005}
]

batch_size = 16
epochs = 100

# %%
tuning_results = []

for params in param_grid:
    
    print("Testing:", params)
    
    tuned_model = build_model(
        model_type=best_model_name,
        units=params["units"],
        learning_rate=params["learning_rate"]
    )
    
    history = tuned_model.fit(
        X_train,
        y_train,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=batch_size,
        verbose=0
    )
    
    val_loss = min(
        history.history["val_loss"]
    )
    
    tuning_results.append({
        "Units": params["units"],
        "Learning Rate": params["learning_rate"],
        "Batch Size": batch_size,
        "Epochs": epochs,
        "Validation Loss": val_loss
    })
# Out:
# Testing: {'units': 32, 'learning_rate': 0.001}
# C:\Users\Administrator\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Testing: {'units': 32, 'learning_rate': 0.0005}
# Testing: {'units': 64, 'learning_rate': 0.001}
# Testing: {'units': 64, 'learning_rate': 0.0005}

# %%
tuning_df = pd.DataFrame(
    tuning_results
)

tuning_df = tuning_df.sort_values(
    "Validation Loss"
).reset_index(drop=True)

tuning_df
# Out:
#    Units  Learning Rate  Batch Size  Epochs  Validation Loss
# 0     64         0.0010          16     100         0.001711
# 1     32         0.0010          16     100         0.002321
# 2     64         0.0005          16     100         0.002477
# 3     32         0.0005          16     100         0.003069

# %%
best_params = tuning_df.iloc[0]

print("Best Hyperparameters:")
print(best_params)
# Out:
# Best Hyperparameters:
# Units               64.000000
# Learning Rate        0.001000
# Batch Size          16.000000
# Epochs             100.000000
# Validation Loss      0.001711
# Name: 0, dtype: float64

# %%
final_model = build_model(
    model_type=best_model_name,
    units=int(best_params["Units"]),
    learning_rate=float(
        best_params["Learning Rate"]
    )
)

final_history = final_model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=int(best_params["Epochs"]),
    batch_size=int(best_params["Batch Size"]),
    verbose=1
)
# Out:
# Epoch 1/100
# C:\Users\Administrator\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - loss: 0.1066 - val_loss: 0.0197
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0193 - val_loss: 0.1002
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0207 - val_loss: 0.0173
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0080 - val_loss: 0.0058
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0044 - val_loss: 0.0190
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0044 - val_loss: 0.0091
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0026 - val_loss: 0.0039
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0026 - val_loss: 0.0064
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0024 - val_loss: 0.0050
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0020 - val_loss: 0.0045
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0021 - val_loss: 0.0036
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0020 - val_loss: 0.0033
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0019 - val_loss: 0.0036
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0019 - val_loss: 0.0034
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0020 - val_loss: 0.0029
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0017 - val_loss: 0.0035
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0019 - val_loss: 0.0028
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 178ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0016 - val_loss: 0.0034
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0015 - val_loss: 0.0029
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0017 - val_loss: 0.0050
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.0014 - val_loss: 0.0029
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0013 - val_loss: 0.0026
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0014 - val_loss: 0.0030
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - loss: 0.0013 - val_loss: 0.0027
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0014 - val_loss: 0.0029
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0014 - val_loss: 0.0042
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0013 - val_loss: 0.0041
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0014 - val_loss: 0.0036
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - loss: 0.0014 - val_loss: 0.0028
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0013 - val_loss: 0.0025
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0013 - val_loss: 0.0026
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0018 - val_loss: 0.0067
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0017 - val_loss: 0.0039
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0014 - val_loss: 0.0030
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0014 - val_loss: 0.0030
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0013 - val_loss: 0.0043
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0014 - val_loss: 0.0044
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0013 - val_loss: 0.0057
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0014 - val_loss: 0.0028

# %%
plt.figure(figsize=(10, 5))

plt.plot(
    final_history.history["loss"],
    label="Training Loss"
)

plt.plot(
    final_history.history["val_loss"],
    label="Validation Loss"
)

plt.title(
    f"Tuned {best_model_name} - Training vs Validation Loss"
)

plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.legend()
plt.grid(True)

plt.show()

# %%
# Hyperparameter Tuning:
# Hyperparameter tuning was performed on the best-performing recurrent architecture identified during the initial model comparison.

# The number of hidden units and learning rate were varied systematically across multiple configurations. A validation dataset was used to compare the configurations and select the model with the lowest validation loss.

# The selected configuration was then retrained using the training data and evaluated on the unseen test set. This approach helps determine whether modifying the training configuration can improve forecasting performance while reducing the risk of overfitting.

# %%
# Part 8 — Evaluate the Tuned Model

final_pred_scaled = final_model.predict(X_test)

final_pred = scaler.inverse_transform(
    final_pred_scaled
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step

# %%
rmse_final = np.sqrt(
    mean_squared_error(
        y_test_actual,
        final_pred
    )
)

mae_final = mean_absolute_error(
    y_test_actual,
    final_pred
)

mape_final = np.mean(
    np.abs(
        (y_test_actual - final_pred) /
        y_test_actual
    )
) * 100

print("Tuned Model Performance")
print("------------------------")
print("RMSE:", rmse_final)
print("MAE :", mae_final)
print("MAPE:", mape_final, "%")
# Out:
# Tuned Model Performance
# ------------------------
# RMSE: 13.217894885828718
# MAE : 10.829350062779017
# MAPE: 1.2769673268194628 %

# %%
final_comparison = pd.DataFrame({
    "Model": [
        "Basic RNN",
        "LSTM",
        "GRU",
        f"Tuned {best_model_name}"
    ],
    "RMSE": [
        rmse_rnn,
        rmse_lstm,
        rmse_gru,
        rmse_final
    ],
    "MAE": [
        mae_rnn,
        mae_lstm,
        mae_gru,
        mae_final
    ],
    "MAPE (%)": [
        mape_rnn,
        mape_lstm,
        mape_gru,
        mape_final
    ]
})

final_comparison
# Out:
#              Model       RMSE        MAE  MAPE (%)
# 0        Basic RNN  13.239509  10.712367  1.265421
# 1             LSTM  29.078996  25.335345  2.960924
# 2              GRU  31.967451  28.965528  3.400678
# 3  Tuned Basic RNN  13.217895  10.829350  1.276967

# %%
best_final_model = final_comparison.loc[
    final_comparison["RMSE"].idxmin(),
    "Model"
]

print("Final Best Model:", best_final_model)
# Out:
# Final Best Model: Tuned Basic RNN

# %%
plt.figure(figsize=(12, 5))

plt.plot(
    y_test_actual,
    label="Actual"
)

plt.plot(
    final_pred,
    label=f"Tuned {best_model_name}"
)

plt.title(
    f"Actual vs Predicted - Tuned {best_model_name}"
)

plt.xlabel("Test Time Step")
plt.ylabel("Milk Production")

plt.legend()
plt.grid(True)

plt.show()

# %%
# Tuned Model Evaluation:
# The selected hyperparameter configuration was evaluated on the unseen test dataset.

# RMSE, MAE, and MAPE were calculated using predictions transformed back to the original milk-production scale. The tuned model was then compared with the original Basic RNN, LSTM, and GRU models.

# The model with the lowest forecasting error is considered the best-performing model for this dataset. The final evaluation is performed only after hyperparameter selection to maintain a clear separation between validation and test data.

# %%
# Part 9 — 12-Month Future Forecast

last_12_months = scaler.transform(
    data[-window_size:]
)
current_sequence = last_12_months.reshape(1, window_size, 1)

print("Input shape:", current_sequence.shape)
# Out:
# Input shape: (1, 12, 1)

# %%
future_predictions_scaled = []

for i in range(12):

    next_prediction = final_model.predict(
        current_sequence,
        verbose=0
    )

    future_predictions_scaled.append(
        next_prediction[0, 0]
    )

    current_sequence = np.concatenate(
        [
            current_sequence[:, 1:, :],
            next_prediction.reshape(1, 1, 1)
        ],
        axis=1
    )

print("Number of predictions:", len(future_predictions_scaled))
print(future_predictions_scaled)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001FD3B85BE20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Number of predictions: 12
# [np.float32(0.7341493), np.float32(0.6473594), np.float32(0.85403794), np.float32(0.8877014), np.float32(1.0192094), np.float32(0.969863), np.float32(0.89409703), np.float32(0.8157059), np.float32(0.71739674), np.float32(0.735062), np.float32(0.65534914), np.float32(0.7319279)]

# %%
future_predictions = scaler.inverse_transform(
    np.array(future_predictions_scaled).reshape(-1, 1)
).flatten()

print("Future predictions:")
print(future_predictions)
# Out:
# Future predictions:
# [838.58405 804.8228  885.2207  898.3158  949.4725  930.27673 900.8037
#  870.3096  832.0674  838.9391  807.9308  837.72   ]

# %%
last_date = df["Date"].max()

future_dates = pd.date_range(
    start=last_date + pd.DateOffset(months=1),
    periods=12,
    freq="MS"
)

forecast_df = pd.DataFrame({
    "Date": future_dates,
    "Forecasted Production": future_predictions
})

forecast_df
# Out:
#          Date  Forecasted Production
# 0  1976-01-01             838.584045
# 1  1976-02-01             804.822815
# 2  1976-03-01             885.220703
# 3  1976-04-01             898.315796
# 4  1976-05-01             949.472473
# 5  1976-06-01             930.276733
# 6  1976-07-01             900.803711
# 7  1976-08-01             870.309570
# 8  1976-09-01             832.067383
# 9  1976-10-01             838.939087
# 10 1976-11-01             807.930786
# 11 1976-12-01             837.719971

# %%
plt.figure(figsize=(14, 6))

plt.plot(
    df["Date"],
    df["Production"],
    label="Historical Production"
)

plt.plot(
    forecast_df["Date"],
    forecast_df["Forecasted Production"],
    marker="o",
    label=f"12-Month Forecast ({best_final_model})"
)

plt.title("12-Month Milk Production Forecast")
plt.xlabel("Date")
plt.ylabel("Milk Production")

plt.legend()
plt.grid(True)

plt.show()

# %%
# Part 10 — Business Insights & Final Conclusion

forecast_df["Change"] = (
    forecast_df["Forecasted Production"].diff()
)

forecast_df
# Out:
#          Date  Forecasted Production     Change
# 0  1976-01-01             838.584045        NaN
# 1  1976-02-01             804.822815 -33.761230
# 2  1976-03-01             885.220703  80.397888
# 3  1976-04-01             898.315796  13.095093
# 4  1976-05-01             949.472473  51.156677
# 5  1976-06-01             930.276733 -19.195740
# 6  1976-07-01             900.803711 -29.473022
# 7  1976-08-01             870.309570 -30.494141
# 8  1976-09-01             832.067383 -38.242188
# 9  1976-10-01             838.939087   6.871704
# 10 1976-11-01             807.930786 -31.008301
# 11 1976-12-01             837.719971  29.789185

# %%
first_forecast = forecast_df[
    "Forecasted Production"
].iloc[0]

last_forecast = forecast_df[
    "Forecasted Production"
].iloc[-1]

percentage_change = (
    (last_forecast - first_forecast)
    / first_forecast
) * 100

print(
    "Forecast change:",
    round(percentage_change, 2),
    "%"
)
# Out:
# Forecast change: -0.1 %

# %%
max_row = forecast_df.loc[
    forecast_df["Forecasted Production"].idxmax()
]

min_row = forecast_df.loc[
    forecast_df["Forecasted Production"].idxmin()
]

print(
    "Highest forecast:",
    max_row["Date"],
    "->",
    round(max_row["Forecasted Production"], 2)
)

print(
    "Lowest forecast:",
    min_row["Date"],
    "->",
    round(min_row["Forecasted Production"], 2)
)
# Out:
# Highest forecast: 1976-05-01 00:00:00 -> 949.47
# Lowest forecast: 1976-02-01 00:00:00 -> 804.82

# %%
# Business Insights and Recommendations:
# The 12-month forecast provides an estimate of future milk production and can support operational and production planning decisions.

# %%
# Key Insights:
# Production Planning Forecasted production can help management estimate future production levels and prepare operational plans accordingly.

# Resource Allocation Expected changes in production can help with planning feed, labor, storage, transportation, and other operational resources.

# Inventory Management Forecast information can support better planning of storage capacity and inventory requirements.

# Capacity Planning Periods with relatively higher predicted production may require additional processing or storage capacity.

# Demand and Supply Planning Forecasts can be compared with expected demand to identify potential periods of surplus or insufficient production.

# %%
# Limitations:
# The forecasts are model-based estimates and should not be treated as guaranteed production values. Because the 12-month forecast is generated recursively, prediction errors can accumulate over longer forecasting horizons.

# The model also uses historical milk production as the primary input, so external factors such as weather, feed availability, livestock health, market conditions, and operational changes are not explicitly represented.

# Therefore, the forecasts should be combined with domain knowledge and other relevant business information when making decisions.

# %%
# Final Conclusion:
# This project developed a deep learning-based time-series forecasting system for monthly milk production.

# The historical production data was explored and prepared using chronological train, validation, and test splits. Min-Max scaling and a 12-month sliding window were used to prepare the sequential data for deep learning.

# Three recurrent neural network architectures were developed: Basic RNN, LSTM, and GRU. Their forecasting performance was evaluated using RMSE, MAE, and MAPE.

# Hyperparameter tuning was then performed on the best-performing architecture to investigate whether changes in the number of hidden units and learning rate could improve forecasting performance.

# Finally, the selected tuned model was used to generate a 12-month future forecast. The forecast can support production planning, resource allocation, inventory management, and capacity planning.

# Although the model provides useful forecasting information, its predictions are subject to uncertainty and should be interpreted alongside external business factors and domain knowledge.
