# %%
# ESTIMATION AND CONFIDENCE INTERVALS :
# Background
# In quality control processes, especially when dealing with high-value items, destructive sampling is a necessary but costly method to ensure product quality. The test to determine whether an item meets the quality standards destroys the item, leading to the requirement of small sample sizes due to cost constraints.
# Scenario
# A manufacturer of print-heads for personal computers is interested in estimating the mean durability of their print-heads in terms of the number of characters printed before failure. To assess this, the manufacturer conducts a study on a small sample of print-heads due to the destructive nature of the testing process.
# Data
# A total of 15 print-heads were randomly selected and tested until failure. The durability of each print-head (in millions of characters) was recorded as follows: 1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.20, 1.33, 1.18, 1.22, 1.29

# %%
# Assignment Tasks:

# a. Build 99% Confidence Interval Using Sample Standard Deviation Assuming the sample is representative 
# of the population, construct a 99% confidence interval for the mean number of characters printed before
# the print-head fails using the sample standard deviation. Explain the steps you take and the rationale
# behind using the t-distribution for this task.

# %%
# Import libraries
import numpy as np
from scipy.stats import t, norm

# Sample data
data = [1.13, 1.55, 1.43, 0.92, 1.25,
        1.36, 1.32, 0.85, 1.07, 1.48,
        1.20, 1.33, 1.18, 1.22, 1.29]

# Sample size
n = len(data)

# Sample mean
mean = np.mean(data)

# Sample standard deviation
sample_std = np.std(data, ddof=1)
print("Sample Size (n):", n)
print("Sample Mean:", round(mean, 4))
print("Sample Standard Deviation:", round(sample_std, 4))


# Confidence level
confidence = 0.99
alpha = 1 - confidence

# Degrees of freedom
df = n - 1

# t critical value
t_critical = t.ppf(1 - alpha/2, df)

# Standard Error
SE = sample_std / np.sqrt(n)

# Margin of Error
ME = t_critical * SE

# Confidence Interval
lower = mean - ME
upper = mean + ME
print("\n99% Confidence Interval (t-distribution)")
print("t Critical Value:", round(t_critical, 4))
print("Standard Error:", round(SE, 4))
print("Margin of Error:", round(ME, 4))
print("Confidence Interval: ({:.4f}, {:.4f})".format(lower, upper))
# Out:
# Sample Size (n): 15
# Sample Mean: 1.2387
# Sample Standard Deviation: 0.1932
#
# 99% Confidence Interval (t-distribution)
# t Critical Value: 2.9768
# Standard Error: 0.0499
# Margin of Error: 0.1485
# Confidence Interval: (1.0902, 1.3871)

# %%
# b. Build 99% Confidence Interval Using Known Population Standard Deviation If it were known that the
# population standard deviation is 0.2 million characters, construct a 99% confidence interval for the
# mean number of characters printed before failure.

# %%
import numpy as np
from scipy.stats import t, norm

# Known population standard deviation
population_std = 0.2

# z critical value
z_critical = norm.ppf(1 - alpha/2)

# Standard Error
SE = population_std / np.sqrt(n)

# Margin of Error
ME = z_critical * SE

# Confidence Interval
lower = mean - ME
upper = mean + ME
print("\n99% Confidence Interval (Z-distribution)")
print("Z Critical Value:", round(z_critical, 4))
print("Standard Error:", round(SE, 4))
print("Margin of Error:", round(ME, 4))
print("Confidence Interval: ({:.4f}, {:.4f})".format(lower, upper))
# Out:
# 99% Confidence Interval (Z-distribution)
# Z Critical Value: 2.5758
# Standard Error: 0.0516
# Margin of Error: 0.133
# Confidence Interval: (1.1057, 1.3717)
